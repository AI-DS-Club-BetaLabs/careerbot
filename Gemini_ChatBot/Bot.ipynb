# %%
import os
import google.generativeai as genai

os.environ['GOOGLE_API_KEY'] = "AIzaSyAWA6Vjzqyd9piW0lIXSHAJqEKjY0UpZwA"
genai.configure(api_key = os.environ['GOOGLE_API_KEY'])
model = genai.GenerativeModel('gemini-pro')

# %%
pip install --upgrade jupyter
# Out:
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting notebook (from jupyter)
#   Downloading notebook-7.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter)
#   Downloading qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter)
#   Downloading nbconvert-7.16.1-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: ipykernel in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter) (6.29.2)
# Collecting ipywidgets (from jupyter)
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (8.22.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (6.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipykernel->jupyter) (5.14.1)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets->jupyter)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets->jupyter)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-console->jupyter) (3.0.42)
# Requirement already satisfied: pygments in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-console->jupyter) (2.17.2)
# Collecting beautifulsoup4 (from nbconvert->jupyter)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert->jupyter)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: jinja2>=3.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from nbconvert->jupyter) (3.1.3)
# Collecting jupyterlab-pygments (from nbconvert->jupyter)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter)
#   Downloading nbclient-0.9.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter)
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert->jupyter)
#   Downloading tinycss2-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter)
#   Downloading jupyter_server-2.12.5-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.22.1 (from notebook->jupyter)
#   Downloading jupyterlab_server-2.25.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.2,>=4.1.1 (from notebook->jupyter)
#   Downloading jupyterlab-4.1.2-py3-none-any.whl.metadata (15 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter)
#   Downloading QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: six>=1.9.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: decorator in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.2.0)
# Requirement already satisfied: colorama in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.3.0)
# Collecting argon2-cffi (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading jupyter_events-0.9.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading jupyter_server_terminals-0.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading pywinpty-2.0.12-cp310-none-win_amd64.whl.metadata (5.2 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading Send2Trash-1.8.2-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading terminado-0.18.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.2,>=4.1.1->notebook->jupyter)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.2,>=4.1.1->notebook->jupyter)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.2,>=4.1.1->notebook->jupyter)
#   Downloading jupyter_lsp-2.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting tomli (from jupyterlab<4.2,>=4.1.1->notebook->jupyter)
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading Babel-2.14.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading json5-0.9.17-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.21.1)
# Requirement already satisfied: requests>=2.31 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Collecting fastjsonschema (from nbformat>=5.7->nbconvert->jupyter)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: wcwidth in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: idna>=2.8 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (4.9.0)
# Requirement already satisfied: certifi in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter)
#   Downloading httpcore-1.0.4-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.18.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.2.1)
# Collecting argon2-cffi-bindings (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.4)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading types_python_dateutil-2.8.19.20240106-py3-none-any.whl.metadata (1.8 kB)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ----------------- ---------------------- 61.4/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 2.1 MB/s eta 0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading nbconvert-7.16.1-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/257.3 kB ? eta -:--:--
#    ----------------------- ---------------- 153.6/257.3 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 257.3/257.3 kB 3.2 MB/s eta 0:00:00
# Downloading notebook-7.1.0-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.0 MB 4.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/5.0 MB 4.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.5/5.0 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.7/5.0 MB 4.6 MB/s eta 0:00:01
#    ------- -------------------------------- 0.9/5.0 MB 4.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.1/5.0 MB 4.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.4/5.0 MB 4.6 MB/s eta 0:00:01
#    ------------ --------------------------- 1.6/5.0 MB 4.8 MB/s eta 0:00:01
#    --------------- ------------------------ 1.9/5.0 MB 5.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.1/5.0 MB 5.2 MB/s eta 0:00:01
#    ------------------- -------------------- 2.4/5.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.7/5.0 MB 5.5 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------- -------------- 3.2/5.0 MB 5.6 MB/s eta 0:00:01
#    --------------------------- ------------ 3.4/5.0 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.7/5.0 MB 5.6 MB/s eta 0:00:01
#    -------------------------------- ------- 4.1/5.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.2/5.0 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 4.6/5.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 5.0 MB/s eta 0:00:00
# Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#    ---------------------------------------- 0.0/123.4 kB ? eta -:--:--
#    ---------------------------------------- 123.4/123.4 kB 3.6 MB/s eta 0:00:00
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#    ---------------------------------------- 162.8/162.8 kB 9.5 MB/s eta 0:00:00
# Downloading jupyter_server-2.12.5-py3-none-any.whl (380 kB)
#    ---------------------------------------- 0.0/380.3 kB ? eta -:--:--
#    --------------------------------------  378.9/380.3 kB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 380.3/380.3 kB 7.9 MB/s eta 0:00:00
# Downloading jupyterlab-4.1.2-py3-none-any.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    - -------------------------------------- 0.4/11.4 MB 28.0 MB/s eta 0:00:01
#    -- ------------------------------------- 0.8/11.4 MB 10.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.4 MB 11.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.9/11.4 MB 11.9 MB/s eta 0:00:01
#    ------- -------------------------------- 2.3/11.4 MB 11.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.8/11.4 MB 11.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.3/11.4 MB 11.8 MB/s eta 0:00:01
#    ------------- -------------------------- 4.0/11.4 MB 12.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.4 MB 12.9 MB/s eta 0:00:01
#    ------------------ --------------------- 5.3/11.4 MB 13.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.4 MB 13.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.4 MB 13.2 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.4 MB 13.7 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.4 MB 13.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.4 MB 13.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.3/11.4 MB 14.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.4 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.4 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.4 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.4 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.4 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 12.3 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.25.3-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#    ---------------------------------------- 59.0/59.0 kB 1.5 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    --------------------------------------- 215.0/215.0 kB 13.7 MB/s eta 0:00:00
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/48.0 kB ? eta -:--:--
#    ---------------------------------------- 48.0/48.0 kB 2.5 MB/s eta 0:00:00
# Downloading nbclient-0.9.0-py3-none-any.whl (24 kB)
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    ---------------------------------------- 77.6/77.6 kB ? eta 0:00:00
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.5 kB ? eta -:--:--
#    ---------------------------------------- 93.5/93.5 kB 5.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------- ----------------------- 1.0/2.3 MB 30.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.3 MB 24.7 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 20.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 16.3 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 9.2 MB/s eta 0:00:00
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading Babel-2.14.0-py3-none-any.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.1/11.0 MB 23.7 MB/s eta 0:00:01
#    ------- -------------------------------- 2.1/11.0 MB 22.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.0 MB 21.3 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/11.0 MB 22.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.9/11.0 MB 22.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.1/11.0 MB 22.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.0 MB 24.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.3/11.0 MB 24.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 24.9 MB/s eta 0:00:01
#    ---------------------------------------  10.8/11.0 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 18.7 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 2.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.8 kB ? eta -:--:--
#    ---------------------------------------- 77.8/77.8 kB 4.2 MB/s eta 0:00:00
# Downloading json5-0.9.17-py2.py3-none-any.whl (23 kB)
# Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Downloading jupyter_lsp-2.2.2-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.8 kB ? eta -:--:--
#    ---------------------------------------- 68.8/68.8 kB 3.9 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading terminado-0.18.0-py3-none-any.whl (14 kB)
# Downloading pywinpty-2.0.12-cp310-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------  1.4/1.4 MB 44.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 29.8 MB/s eta 0:00:00
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading jupyter_server_terminals-0.5.2-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.9 MB/s eta 0:00:00
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.5 kB ? eta -:--:--
#    ---------------------------------------- 58.5/58.5 kB ? eta 0:00:00
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Downloading cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    ---------------------------------------- 181.6/181.6 kB 5.4 MB/s eta 0:00:00
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#    ---------------------------------------- 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#    ---------------------------------------- 118.7/118.7 kB 3.5 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.8.19.20240106-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, types-python-dateutil, tomli, tinycss2, soupsieve, send2trash, rfc3986-validator, rfc3339-validator, qtpy, pywinpty, python-json-logger, pycparser, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, json5, h11, fqdn, defusedxml, bleach, babel, async-lru, terminado, httpcore, cffi, beautifulsoup4, arrow, jupyter-server-terminals, isoduration, httpx, argon2-cffi-bindings, nbformat, ipywidgets, argon2-cffi, qtconsole, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 babel-2.14.0 beautifulsoup4-4.12.3 bleach-6.1.0 cffi-1.16.0 defusedxml-0.7.1 fastjsonschema-2.19.1 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 ipywidgets-8.1.2 isoduration-20.11.0 json5-0.9.17 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.9.0 jupyter-lsp-2.2.2 jupyter-server-2.12.5 jupyter-server-terminals-0.5.2 jupyterlab-4.1.2 jupyterlab-pygments-0.3.0 jupyterlab-server-2.25.3 jupyterlab-widgets-3.0.10 mistune-3.0.2 nbclient-0.9.0 nbconvert-7.16.1 nbformat-5.9.2 notebook-7.1.0 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.20.0 pycparser-2.21 python-json-logger-2.0.7 pywinpty-2.0.12 qtconsole-5.5.1 qtpy-2.4.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.2 soupsieve-2.5 terminado-0.18.0 tinycss2-1.2.1 tomli-2.0.1 types-python-dateutil-2.8.19.20240106 uri-template-1.3.0 webcolors-1.13 webencodings-0.5.1 websocket-client-1.7.0 widgetsnbextension-4.0.10
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wsdump.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script send2trash.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script qtpy.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyjson5.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-events.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-console.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-dejavu.exe and jupyter-nbconvert.exe are installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jlpm.exe, jupyter-lab.exe, jupyter-labextension.exe and jupyter-labhub.exe are installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-notebook.exe is installed in 'c:\Obsidians\Academics\Projects\Chatbot\GeminiBot\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (8.1.2)
# Requirement already satisfied: comm>=0.1.3 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipywidgets) (8.22.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipywidgets) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: decorator in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: colorama in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\obsidians\academics\projects\chatbot\geminibot\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
