# %%
import os
import google.generativeai as genai

os.environ['GOOGLE_API_KEY'] = "AIzaSyAWA6Vjzqyd9piW0lIXSHAJqEKjY0UpZwA"
genai.configure(api_key = os.environ['GOOGLE_API_KEY'])

model = genai.GenerativeModel('gemini-pro')

response = model.generate_content("List 5 planets each with an interesting fact")
print(response.text)

response = model.generate_content("what are top 5 frequently used emojis?")
print(response.text)
# Out:
# **1. Mercury:**
# - Mercury is the smallest and closest planet to the Sun.
# - It has no moons and is the only rocky planet without an atmosphere.
# - Mercury's surface temperature can reach up to 450 degrees Celsius, making it the hottest planet in the solar system.
#
# **2. Venus:**
# - Venus is the second closest planet to the Sun and is often referred to as Earth's twin due to its similar size and composition.
# - It has a thick atmosphere primarily composed of carbon dioxide, which traps heat and creates a runaway greenhouse effect, making it the hottest planet in the solar system.
# - Venus rotates very slowly, taking 243 Earth days to complete one rotation.
#
# **3. Earth:**
# - Earth is the only planet known to support life and is home to a diverse range of ecosystems.
# - It has a thin atmosphere composed of 78% nitrogen, 21% oxygen, and trace amounts of other gases.
# - Earth's surface is covered by 71% water, forming oceans, seas, and lakes.
#
# **4. Mars:**
# ...

# %%
import re

def is_career_related(question):
    # Define regular expressions for career-related patterns
    career_patterns = [
        r"career.*\b(?:specialized|expertise|experienced|background|field|industry|sector|path|prospect|job|role|opportunity|option|choice|possibility|future|occupation|vocation|profession|employment)\b",
        r"\b(?:options|opportunities|paths|prospects|choices|fields|sectors|industries|jobs|careers)\b.*\b(?:in|for|related to|within|available in)\b.*\b(?:chemical engineering|CSC|computer science|AI|artificial intelligence|ML|machine learning|data science|data analysis|data engineering|data visualization|business analytics|statistics|finance|accounting|economics|marketing|advertising|sales|management|medicine|healthcare|nursing|pharmacy|physical therapy|occupational therapy|dentistry|law|legal|criminal justice|criminology|business|management|entrepreneurship|education|teaching|instruction|training|design|graphic design|interior design|product design|industrial design|creative|art|fine arts|performing arts|music|dance|theater|film|media|communication|journalism|public relations|entertainment|sports|fitness|nutrition|coaching|exercise science|physical education|culinary arts|hospitality|tourism|event management|restaurant management|travel|aviation|aerospace|engineering|civil engineering|mechanical engineering|electrical engineering|chemical engineering|biomedical engineering|computer engineering|software engineering|information technology|IT|computer science|programming|web development|software development|networking|cybersecurity|telecommunications|biotechnology|pharmaceuticals|genetics|environmental science|sustainability|energy|renewable energy|environmental engineering|agriculture|food science|agronomy|forestry|marine science|oceanography|geology|earth science|physics|chemistry|mathematics|statistics|operations research|supply chain management|logistics|transportation|manufacturing|production|quality assurance|architecture|urban planning|landscape architecture|interior architecture|construction|real estate|property management|social work|psychology|counseling|human resources|personnel management)\b"
    ]

    # Check if the question matches any career-related pattern
    for pattern in career_patterns:
        if re.search(pattern, question, re.IGNORECASE):
            return True
    return False

q="I am experienced in AI/ML and have a BTech in Computer Science, what job should I go for?"
if is_career_related(q):
    response = model.generate_content(q)
    print(response.text)
else:
    print("Not a career related question")
# Out:
# Not a career related question

# %%
'''response = model.generate_content("What is Quantum Computing?",
                                  generation_config = genai.types.GenerationConfig(
                                  candidate_count = 1,
                                  stop_sequences = ['.'],
                                  max_output_tokens = 40,
                                  top_p = 0.6,
                                  top_k = 5,
                                  temperature = 0.8)
                                )
print(response.text)'''
'''
import re

def is_career_related(question):
    # Define regular expressions for career-related patterns
    career_patterns = [
        r"career.*\b(?:specialized|expertise|experienced|background|field|industry|sector|path|prospect|job|role|opportunity|option|choice|possibility|future|occupation|vocation|profession|employment)\b",
        r"\b(?:options|opportunities|paths|prospects|choices|fields|sectors|industries|jobs|careers)\b.*\b(?:in|for|related to|within|available in)\b.*\b(?:chemical engineering|CSC|computer science|AI|artificial intelligence|ML|machine learning|data science|data analysis|data engineering|data visualization|business analytics|statistics|finance|accounting|economics|marketing|advertising|sales|management|medicine|healthcare|nursing|pharmacy|physical therapy|occupational therapy|dentistry|law|legal|criminal justice|criminology|business|management|entrepreneurship|education|teaching|instruction|training|design|graphic design|interior design|product design|industrial design|creative|art|fine arts|performing arts|music|dance|theater|film|media|communication|journalism|public relations|entertainment|sports|fitness|nutrition|coaching|exercise science|physical education|culinary arts|hospitality|tourism|event management|restaurant management|travel|aviation|aerospace|engineering|civil engineering|mechanical engineering|electrical engineering|chemical engineering|biomedical engineering|computer engineering|software engineering|information technology|IT|computer science|programming|web development|software development|networking|cybersecurity|telecommunications|biotechnology|pharmaceuticals|genetics|environmental science|sustainability|energy|renewable energy|environmental engineering|agriculture|food science|agronomy|forestry|marine science|oceanography|geology|earth science|physics|chemistry|mathematics|statistics|operations research|supply chain management|logistics|transportation|manufacturing|production|quality assurance|architecture|urban planning|landscape architecture|interior architecture|construction|real estate|property management|social work|psychology|counseling|human resources|personnel management)\b"
    ]

    # Check if the question matches any career-related pattern
    for pattern in career_patterns:
        if re.search(pattern, question, re.IGNORECASE):
            return True
    return False

q=input()
if is_career_related(q):
    response = model.generate_content(q)
    print(response.text)
else:
    print("Not a career related question")'''

response = model.generate_content("I am experienced in AI/ML and have a BTech in Computer Science, what should I do?")
print(response.text)
# Out:
# 1. **Apply for Higher Education:**
#     - Consider pursuing a Master's degree (MS) or a Doctorate (PhD) in a relevant field of study, such as Artificial Intelligence, Machine Learning, Computer Science, or related disciplines. This could provide you with advanced knowledge, research opportunities, and further enhance your skills.
#
#
# 2. **Look for Research Roles:**
#     - Seek out research positions in academia, research labs, or R&D departments of technology companies.
#     - Explore opportunities at universities, government research institutions, and private organizations conducting cutting-edge research in AI/ML.
#
#
# 3. **Join an AI/ML Startup:**
#     - Look for AI/ML startup companies that are working on innovative products and solutions.
#     - Startups may offer exciting challenges, autonomy, and the opportunity to contribute to the development of new technologies.
#
#
# 4. **Consider Freelancing or Consulting:**
# ...
